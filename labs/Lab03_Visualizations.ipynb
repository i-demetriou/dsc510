# %% [markdown]
# # Lab 3 – Visualizations
#
# In this lab, you will practice creating a variety of visualizations using the Seaborn library.

# %% [markdown]
# ## Dataset
# We will use the **Penguins dataset** from Seaborn (similar to the one on Kaggle). It contains measurements for penguin species, including features such as bill length, bill depth, flipper length, body mass, and sex.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the dataset
penguins = sns.load_dataset('penguins')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ## 1. Histograms
# **Purpose:** Understand the distribution of numerical variables, detect skewness, and spot outliers.
# ### Exercise 1: Create a histogram of body mass.
# *Goal*: Understand the distribution of penguin body mass.
#
# *Task*: Plot a histogram of `bill_length_mm` with a KDE curve. Use the `kde=True` parameter to show a smooth estimation of the distribution.
#
# *Interpretation*: Check if the distribution is symmetric, skewed, or multimodal.

# %%
fig,ax = plt.subplots()
None
# Out:
# Text(0.5, 0, 'Body Mass')

# %% [markdown]
# ### Exercise 2: Histogram of body mass by species
#
# *Goal*: Compare body mass distributions across species.
#
# *Task*: Plot histograms of `body_mass_g`, colored by `species`. Use `multiple='stack'` so that the densities are stacked on each other.
#
# *Interpretation*: Identify which species tend to be heavier and whether distributions overlap.

# %%
fig,ax = plt.subplots()
None
# Out:
# Text(0.5, 0, 'Body Mass')

# %% [markdown]
# ## 2. Box Plots
# **Purpose:** Compare distributions across categories, identify medians, quartiles, and outliers.
# ### Exercise 1: Box plot of body mass by species
#
# *Goal*: Compare the central tendency and variability of body mass across species.
#
# *Task*: Create a box plot of `body_mass_g` grouped by `species`. Set the `species` feature on the x-axis and the `body_mass_g` feature on the y-axis.
#
# *Interpretation*: Which species has the largest median body mass? Are there outliers?

# %%
fig, ax = plt.subplots()
None
# Out:
# Text(0, 0.5, 'Body Mass (g)')

# %% [markdown]
# ### Exercise 2: Box plot of flipper length by species and sex
#
# *Goal*: Examine differences in flipper length between sexes within species.
#
# Task: Create a box plot of `flipper_length_mm`, grouped by species and split by `sex`. Set the `species` feature on the x-axis and the `flipper_length_mm` feature on the y-axis.
#
# *Interpretation*: Do males and females show consistent differences? Are some species more variable than others?

# %%
fig, ax = plt.subplots()
None
# Out:
# Text(0, 0.5, 'Flipper Length (mm)')

# %% [markdown]
# ## 3. Violin Plots
# **Purpose:** Show distribution, density, and multimodality for each category.
# ### Exercise 1: Violin plot of flipper length by species
#
# *Goal*: Visualize the full distribution and density of flipper lengths.
#
# *Task*: Create a violin plot of `flipper_length_mm` by `species`.
#
# *Interpretation*: Look for multimodal distributions and compare species’ density shapes.

# %%
fig, ax = plt.subplots()
None
# Out:
# Text(0, 0.5, 'Flipper Length (mm)')

# %% [markdown]
# ### Exercise 2: Split violin plot by sex to see density differences
#
# *Goal*: Compare flipper lengths between males and females across species.
#
# *Task*: Create a split violin plot of `flipper_length_mm` by `species`, split by `sex` (use `split=True` parameter to show an un-mirrored distribution).
#
# *Interpretation*: Are male penguins consistently larger than females?

# %%
fig, ax = plt.subplots()
None
# Out:
# Text(0, 0.5, 'Flipper Length (mm)')

# %% [markdown]
# ## 4. Pair Plots
# **Purpose:** Explore relationships between multiple numerical variables and identify patterns or correlations.
# ### Exercise 1: Pair plot colored by species
#
# *Goal*: Explore relationships among multiple numeric variables.
#
# *Task*: Create a pair plot of the dataset, with points colored by `species`. Keep in mind that pairplot is a fegure-level plot.
#
# *Interpretation*: Identify variables that best separate species (e.g., body mass vs bill length).

# %%
plt.figure()
None

# %% [markdown]
# ## 5. Line Plots
# **Purpose:** Show trends or relationships between numeric variables.
# ### Exercise 1: Body mass vs flipper length by species
#
# *Goal*: Show how body mass changes with flipper length.
#
# *Task*: Create a line plot with `flipper_length_mm` on the x-axis and `body_mass_g` on the y-axis, colored by species.
#
# *Interpretation*: Do heavier penguins generally have longer flippers? Does the trend vary by species?

# %%
fig, ax = plt.subplots()
None
# Out:
# Text(0, 0.5, 'Body Mass')

# %% [markdown]
# ### Exercise 2: Bill depth vs bill length for each species
#
# *Goal*: Explore the relationship between bill size dimensions.
#
# *Task*: Create a line plot with `bill_length_mm` on the x-axis and `bill_depth_mm` on the y-axis, colored by species.
#
# *Interpretation*: Which species show deeper vs longer bills?

# %%
fig, ax = plt.subplots()
None
# Out:
# Text(0.5, 0, 'Bill Length')

# %% [markdown]
# ## 6. Heatmaps
# **Purpose:** Visualize correlation between numerical variables to detect strong positive or negative relationships.
# ### Exercise 1: Correlation matrix heatmap
#
# *Goal*: Show how body mass changes with flipper length.
#
# *Task*: Create a line plot with `flipper_length_mm` on the x-axis and `body_mass_g` on the y-axis, colored by `species`.
#
# *Interpretation*: Are there any strong correlations between features?

# %%
None
# Out:
# Text(0.5, 1.0, 'Correlation Matrix Heatmap')

# %% [markdown]
# ## 7. Bar Plots
# **Purpose:** Compare aggregated values (mean, sum, etc.) across categories.
# ### Exercise 1: Mean body mass by species

# %%
fig, ax = plt.subplots()
None
# Out:
# Text(0, 0.5, 'Mean Body Mass')

# %% [markdown]
# ### Exercise 2: Mean flipper length by species
#
# *Goal*: Compare the average body mass across species.
#
# *Task*: Create a bar plot showing mean `body_mass_g` for each species.
#
# *Interpretation*: Which species is heaviest on average?

# %%
fig, ax = plt.subplots()
None
# Out:
# Text(0, 0.5, 'Mean Flipper Length')

# %% [markdown]
# ## 8. Count Plots
# **Purpose:** Count occurrences of categorical values to see distribution across categories.
# ### Exercise 1: Count penguins by species
#
# *Goal*: Check the sample size distribution across species.
#
# *Task*: Create a count plot of penguins per `species`.
#
# *Interpretation*: Which species is most represented in the dataset?

# %%
fig, ax = plt.subplots()
None
# Out:
# Text(0.5, 1.0, 'Count of Penguins by Species')

# %% [markdown]
# ### Exercise 2: Count penguins by species and sex
#
# *Goal*: Examine sex distribution within each species.
#
# *Task*: Create a count plot of penguins by `species`, separated by `sex`.
#
# *Interpretation*: Are the sexes balanced within each species?

# %%
fig, ax = plt.subplots()
None
# Out:
# Text(0.5, 1.0, 'Count of Penguins by Species and Sex')
